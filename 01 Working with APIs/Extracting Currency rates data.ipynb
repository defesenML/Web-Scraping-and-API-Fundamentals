# %% [markdown]
# ## Extracting data on currency exchange rates

# %% [markdown]
# ### Sending a GET request

# %%
import requests

# %%
api_key = 'f77eaAwpXsJGD0Yog4cLnq3dAe7uFE2T'

# %%
url ='https://api.apilayer.com/exchangerates_data/latest'

# %%
header ={'apikey':'f77eaAwpXsJGD0Yog4cLnq3dAe7uFE2T'}

# %%
response=requests.get(url,headers=header)

# %%
response.json()
# Out:
# {'success': True,
#  'timestamp': 1665604564,
#  'base': 'EUR',
#  'date': '2022-10-12',
#  'rates': {'AED': 3.563359,
#   'AFN': 82.969583,
#   'ALL': 116.662418,
#   'AMD': 391.683347,
#   'ANG': 1.748725,
#   'AOA': 426.472003,
#   'ARS': 146.506255,
#   'AUD': 1.546109,
#   'AWG': 1.746293,
#   'AZN': 1.646146,
#   'BAM': 1.953178,
#   'BBD': 1.95914,
#   'BDT': 98.644012,
#   'BGN': 1.956839,
#   'BHD': 0.365843,
#   'BIF': 1990.773753,
#   'BMD': 0.970163,
#   'BND': 1.393144,
#   'BOB': 6.704896,
#   'BRL': 5.135163,
#   'BSD': 0.970282,
#   'BTC': 5.0695973e-05,
#   'BTN': 79.842838,
#   'BWP': 13.024514,
#   'BYN': 2.45986,
#   'BYR': 19015.187896,
#   'BZD': 1.955844,
#   'CAD': 1.340479,
#   'CDF': 1985.923027,
#   'CHF': 0.968057,
#   'CLF': 0.033208,
#   'CLP': 916.31579,
#   'CNY': 6.961014,
#   'COP': 4470.422166,
#   'CRC': 610.940424,
#   'CUC': 0.970163,
#   'CUP': 25.70931,
#   'CVE': 110.744216,
#   'CZK': 24.560347,
#   'DJF': 172.417479,
#   'DKK': 7.438624,
# ...

# %% [markdown]
# ## Investigating the Response

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
print(response.url)
print(response.status_code)
# Out:
# https://api.apilayer.com/exchangerates_data/latest
# 200

# %%
print(response.headers)
# Out:
# {'Date': 'Wed, 12 Oct 2022 19:56:55 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'CF-Ray': '759266cef82002b6-MIA', 'Access-Control-Allow-Origin': '*', 'CF-Cache-Status': 'DYNAMIC', 'cf-apo-via': 'origin,host', 'RateLimit-Limit': '250', 'RateLimit-Remaining': '249', 'RateLimit-Reset': '1569785', 'X-Cloud-Trace-Context': '543c455d48f057d28f796308cde6c17a;o=1', 'X-RateLimit-Limit-Day': '250', 'X-RateLimit-Limit-Month': '250', 'X-RateLimit-Remaining-Day': '249', 'X-RateLimit-Remaining-Month': '249', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=GRE9N6pR44tIsHIl8pzu9xUFDSb3PRuMveue1et0AL3WAE9wn%2Bjr3tylQZNaFmBsNyUyErgZnkcd%2F50dB462vYnQc1XmVdFqs0dFyqV%2FaVFOMYMnbAJZ8f4I7onAgYXZ7lE%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'Content-Encoding': 'br', 'alt-svc': 'h3=":443"; ma=
# ...

# %%
response.text
# Out:
# '{\n    "success": true,\n    "timestamp": 1665604564,\n    "base": "EUR",\n    "date": "2022-10-12",\n    "rates": {\n        "AED": 3.563359,\n        "AFN": 82.969583,\n        "ALL": 116.662418,\n        "AMD": 391.683347,\n        "ANG": 1.748725,\n        "AOA": 426.472003,\n        "ARS": 146.506255,\n        "AUD": 1.546109,\n        "AWG": 1.746293,\n        "AZN": 1.646146,\n        "BAM": 1.953178,\n        "BBD": 1.95914,\n        "BDT": 98.644012,\n        "BGN": 1.956839,\n        "BHD": 0.365843,\n        "BIF": 1990.773753,\n        "BMD": 0.970163,\n        "BND": 1.393144,\n        "BOB": 6.704896,\n        "BRL": 5.135163,\n        "BSD": 0.970282,\n        "BTC": 5.0695973e-05,\n        "BTN": 79.842838,\n        "BWP": 13.024514,\n        "BYN": 2.45986,\n        "BYR": 19015.187896,\n        "BZD": 1.955844,\n        "CAD": 1.340479,\n        "CDF": 1985.923027,\n        "CHF": 0.968057,\n        "CLF": 0.033208,\n        "CLP": 916.31579,\n        "CNY": 6.9610
# ...

# %%
type(response.json())
# Out:
# dict

# %%
import json

# %%
json.dumps(response.json(), indent=4)
# Out:
# '{\n    "success": true,\n    "timestamp": 1665604564,\n    "base": "EUR",\n    "date": "2022-10-12",\n    "rates": {\n        "AED": 3.563359,\n        "AFN": 82.969583,\n        "ALL": 116.662418,\n        "AMD": 391.683347,\n        "ANG": 1.748725,\n        "AOA": 426.472003,\n        "ARS": 146.506255,\n        "AUD": 1.546109,\n        "AWG": 1.746293,\n        "AZN": 1.646146,\n        "BAM": 1.953178,\n        "BBD": 1.95914,\n        "BDT": 98.644012,\n        "BGN": 1.956839,\n        "BHD": 0.365843,\n        "BIF": 1990.773753,\n        "BMD": 0.970163,\n        "BND": 1.393144,\n        "BOB": 6.704896,\n        "BRL": 5.135163,\n        "BSD": 0.970282,\n        "BTC": 5.0695973e-05,\n        "BTN": 79.842838,\n        "BWP": 13.024514,\n        "BYN": 2.45986,\n        "BYR": 19015.187896,\n        "BZD": 1.955844,\n        "CAD": 1.340479,\n        "CDF": 1985.923027,\n        "CHF": 0.968057,\n        "CLF": 0.033208,\n        "CLP": 916.31579,\n        "CNY": 6.9610
# ...

# %%
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "success": true,
#     "timestamp": 1665604564,
#     "base": "EUR",
#     "date": "2022-10-12",
#     "rates": {
#         "AED": 3.563359,
#         "AFN": 82.969583,
#         "ALL": 116.662418,
#         "AMD": 391.683347,
#         "ANG": 1.748725,
#         "AOA": 426.472003,
#         "ARS": 146.506255,
#         "AUD": 1.546109,
#         "AWG": 1.746293,
#         "AZN": 1.646146,
#         "BAM": 1.953178,
#         "BBD": 1.95914,
#         "BDT": 98.644012,
#         "BGN": 1.956839,
#         "BHD": 0.365843,
#         "BIF": 1990.773753,
#         "BMD": 0.970163,
#         "BND": 1.393144,
#         "BOB": 6.704896,
#         "BRL": 5.135163,
#         "BSD": 0.970282,
#         "BTC": 5.0695973e-05,
#         "BTN": 79.842838,
#         "BWP": 13.024514,
#         "BYN": 2.45986,
#         "BYR": 19015.187896,
#         "BZD": 1.955844,
#         "CAD": 1.340479,
#         "CDF": 1985.923027,
#         "CHF": 0.968057,
#         "CLF": 0.033208,
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])

# %% [markdown]
# ## Incorporating parameters in the GET request

# %%
param_url = url + "?symbols=USD,GBP"
param_url
# Out:
# 'https://api.apilayer.com/exchangerates_data/latest?symbols=USD,GBP'

# %%
response = requests.get(param_url, headers=header)
response
# Out:
# <Response [200]>

# %%
data=response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1665606844,
#  'base': 'EUR',
#  'date': '2022-10-12',
#  'rates': {'USD': 0.969749, 'GBP': 0.874437}}

# %%
data['base']
# Out:
# 'EUR'

# %%
data['date']
# Out:
# '2022-10-12'

# %%
data['rates']
# Out:
# {'USD': 0.969749, 'GBP': 0.874437}

# %%
param_url=url+"?symbols=GBP" + "&" + "base=USD"
param_url
# Out:
# 'https://api.apilayer.com/exchangerates_data/latest?symbols=GBP&base=USD'

# %%
data= requests.get(param_url, headers=header).json()
data
# Out:
# {'success': True,
#  'timestamp': 1665607203,
#  'base': 'USD',
#  'date': '2022-10-12',
#  'rates': {'GBP': 0.901665}}

# %%
usd_to_gbp= data['rates']['GBP']
usd_to_gbp
# Out:
# 0.901665

# %% [markdown]
# ## Obtaining historical exchange rates

# %%
base_url = 'https://api.apilayer.com/exchangerates_data'

# %%
historical_url = base_url+ "/2016-01-26"
historical_url
# Out:
# 'https://api.apilayer.com/exchangerates_data/2016-01-26'

# %%
response= requests.get(historical_url, headers=header)
response.status_code
# Out:
# 200

# %%
data=response.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "timestamp": 1453852799,
#     "historical": true,
#     "base": "EUR",
#     "date": "2016-01-26",
#     "rates": {
#         "AED": 3.991061,
#         "AFN": 74.58154,
#         "ALL": 137.965795,
#         "AMD": 530.247142,
#         "ANG": 1.943586,
#         "AOA": 168.999693,
#         "ARS": 14.990112,
#         "AUD": 1.55192,
#         "AWG": 1.948565,
#         "AZN": 1.738253,
#         "BAM": 1.958195,
#         "BBD": 2.173122,
#         "BDT": 85.139638,
#         "BGN": 1.959586,
#         "BHD": 0.409556,
#         "BIF": 1701.160447,
#         "BMD": 1.086561,
#         "BND": 1.550257,
#         "BOB": 7.503896,
#         "BRL": 4.430875,
#         "BSD": 1.086561,
#         "BTC": 0.002759,
#         "BTN": 73.608145,
#         "BWP": 12.59286,
#         "BYR": 22823.99887,
#         "BZD": 2.166505,
#         "CAD": 1.536042,
#         "CDF": 1008.769361,
#         "CHF": 1.104771,
#         "CLF": 0.026732,
# ...

# %% [markdown]
# ## Extracting data for a time period

# %%
time_period = base_url + "/timeseries" + "?start_date=2017-04-26&end_date=2018-04-26" + "&symbols=GBP"
time_period
# Out:
# 'https://api.apilayer.com/exchangerates_data/timeseries?start_date=2017-04-26&end_date=2018-04-26&symbols=GBP'

# %%
data= requests.get(time_period, headers=header).json()

# %%
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "timeseries": true,
#     "start_date": "2017-04-26",
#     "end_date": "2018-04-26",
#     "base": "EUR",
#     "rates": {
#         "2017-04-26": {
#             "GBP": 0.849233
#         },
#         "2017-04-27": {
#             "GBP": 0.842886
#         },
#         "2017-04-28": {
#             "GBP": 0.841437
#         },
#         "2017-04-29": {
#             "GBP": 0.841437
#         },
#         "2017-04-30": {
#             "GBP": 0.843718
#         },
#         "2017-05-01": {
#             "GBP": 0.846159
#         },
#         "2017-05-02": {
#             "GBP": 0.845241
#         },
#         "2017-05-03": {
#             "GBP": 0.846057
#         },
#         "2017-05-04": {
#             "GBP": 0.849792
#         },
#         "2017-05-05": {
#             "GBP": 0.847757
#         },
#         "2017-05-06": {
#             "GBP": 0.847757
#         },
#         "2017-05-07": {
#             "GBP": 0.845862
#         },
# ...

# %%
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "base": "EUR",
#     "end_date": "2018-04-26",
#     "rates": {
#         "2017-04-26": {
#             "GBP": 0.849233
#         },
#         "2017-04-27": {
#             "GBP": 0.842886
#         },
#         "2017-04-28": {
#             "GBP": 0.841437
#         },
#         "2017-04-29": {
#             "GBP": 0.841437
#         },
#         "2017-04-30": {
#             "GBP": 0.843718
#         },
#         "2017-05-01": {
#             "GBP": 0.846159
#         },
#         "2017-05-02": {
#             "GBP": 0.845241
#         },
#         "2017-05-03": {
#             "GBP": 0.846057
#         },
#         "2017-05-04": {
#             "GBP": 0.849792
#         },
#         "2017-05-05": {
#             "GBP": 0.847757
#         },
#         "2017-05-06": {
#             "GBP": 0.847757
#         },
#         "2017-05-07": {
#             "GBP": 0.845862
#         },
#         "2017-05-08": {
#             "GBP": 0.844479
#         },
#         "2017-05-09": {
# ...

# %% [markdown]
# ## Creating a simple currency converter

# %%
date= input("Please enter the date (in the format 'yyyy-mm-dd' or 'latest'): ")
base= input("convert from (currency): ")
curr= input("Convert to (currency): ")
quan= float(input("How much {} do you want to convert: ".format(base)))

url = base_url + "/" + date + "?base" + base + "&symbols=" + curr
response = requests.get(url, headers= header)

if(response.ok is False):
    print("\nError {}:".format(response.status_code))
    print(response.json()['error'])
    
else:
    data= response.json()
    rate= data['rates'][curr]
    
    result= quan*rate
    print("\n{0} {1} is equal to {2} {3}, based upon exchange rates on {4}".format(quan, base, result, curr, data['date']))
# Out:
# Please enter the date (in the format 'yyyy-mm-dd' or 'latest'): 2009-07-03
# convert from (currency): GBP
# Convert to (currency): USD
# How much GBP do you want to convert: 50
#
# 50.0 GBP is equal to 69.96845 USD, based upon exchange rates on 2009-07-03
